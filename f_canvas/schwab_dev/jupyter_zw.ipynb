# %%
#import packages
import schwabdev
import logging
import dotenv
import os
from pathlib import Path

# %%
BASE_DIR = Path.cwd().resolve().parent.parent.parent

# set logging level
logging.basicConfig(level=logging.INFO)

#load environment variables and make client
dotenv.load_dotenv(BASE_DIR/ '.env')
# Out:
# True

# %%
client = schwabdev.Client(os.getenv('APP_KEY'), os.getenv('APP_SECRET'), os.getenv('CALLBACK_URL'))
# del client # To clean up
# Out:
# INFO:Schwabdev:Access token updated at 2026-02-12 16:50:48.163134+00:00
# INFO:Schwabdev:Access token expires in: 0:29:59
# INFO:Schwabdev:Refresh token expires in: 6 days, 10:53:37

# %% [markdown]
# # Basic API calls

# %%
# get account number and hashes for linked accounts
linked_accounts = client.linked_accounts().json()
print(linked_accounts)
# select the first account to use for orders
account_hash = linked_accounts[0].get('hashValue')
# Out:
# [{'accountNumber': '29308909', 'hashValue': '5050E677CA3B9139950404F8253F841A99BCA9528AB8CDC11684488239FA145B'}, {'accountNumber': '36585142', 'hashValue': '19460E8740604DAA0121689FB6B2986D0EC75ED2AFFE5BEF525C67E72CA6C8C4'}]

# %%
# get positions for selected account
print(client.account_details(account_hash, fields="positions").json())
# Out:
# {'securitiesAccount': {'type': 'MARGIN', 'accountNumber': '29308909', 'roundTrips': 0, 'isDayTrader': True, 'isClosingOnlyRestricted': False, 'pfcbFlag': False, 'positions': [{'shortQuantity': 0.0, 'averagePrice': 8.826, 'currentDayProfitLoss': -841.0, 'currentDayProfitLossPercentage': -4.16, 'longQuantity': 2900.0, 'settledLongQuantity': 2900.0, 'settledShortQuantity': 0.0, 'instrument': {'assetType': 'EQUITY', 'cusip': '03945R102', 'symbol': 'ACHR', 'netChange': -0.29}, 'marketValue': 19372.0, 'maintenanceRequirement': 9686.0, 'averageLongPrice': 8.826, 'taxLotAverageLongPrice': 8.826, 'longOpenProfitLoss': -6223.400000000002, 'previousSessionLongQuantity': 2900.0, 'currentDayCost': 0.0}, {'shortQuantity': 0.0, 'averagePrice': 113.98, 'currentDayProfitLoss': -2.4699, 'currentDayProfitLossPercentage': -2.79, 'longQuantity': 1.0, 'settledLongQuantity': 1.0, 'settledShortQuantity': 0.0, 'instrument': {'assetType': 'EQUITY', 'cusip': 'N97284108', 'symbol': 'NBIS', 'netChange': -2.4699}, 'marketValue': 86.14, 'maintenanceRequirement': 43.07, 'averageLongPrice': 98.1, 'taxLotAverageLongPrice': 113.98, 'longOpenProfitLoss': -27.8399, 'previousSessionLongQuantity': 1.0, 'currentDayCost': 0.0}, {'shortQuantity': 0.0, 'averagePrice': 26.575, 'currentDayProfitLoss': -90.25, 'currentDayProfitLossPercentage': -10.91, 'longQuantity': 38.0, 'settledLongQuantity': 38.0, 'settledShortQuantity': 0.0, 'instrument': {'assetType': 'EQUITY', 'cusip': '91733P107', 'symbol': 'USAR', 'netChange': -2.375}, 'marketValue': 737.01, 'maintenanceRequirement': 737.01, 'averageLongPrice': 26.575, 'taxLotAverageLongPrice': 26.575, 'longOpenProfitLoss': -272.84, 'previousSessionLongQuantity': 38.0, 'currentDayCost': 0.0}], 'initialBalances': {'accruedInterest': 0.0, 'availableFundsNonMarginableTrade': 11025.0, 'bondValue': 44098.44, 'buyingPower': 36748.7, 'cashBalance': 873.81, 'cashAvailableForTrading': 0.0, 'cashReceipts': 0.0, 'dayTradingBuyingPower': 0.0, 'dayTradingBuyingPowerCall': 2997.32, 'dayTradingEquityCall': 2997.32, 'equity': 22002.68, 'equityPercentage': 100.0, 'liquidationValue': 22002.68, 'longMarginValue': 21128.87, 'longOptionMarketValue': 0.0, 'longStockValue': 21128.87, 'maintenanceCall': 0.0, 'maintenanceRequirement': 10978.0, 'margin': 873.81, 'marginEquity': 22002.68, 'moneyMarketFund': 0.0, 'mutualFundValue': 11025.0, 'regTCall': 0.0, 'shortMarginValue': 0.0, 'shortOptionMarketValue': 0.0, 'shortStockValue': 0.0, 'totalCash': 0.0, 'isInCall': True, 'pendingDeposits': 0.0, 'marginBalance': 0.0, 'shortBalance': 0.0, 'accountValue': 22002.68}, 'currentBalances': {'accruedInterest': 0.0, 'cashBalance': 873.81, 'cashReceipts': 0.0, 'longOptionMarketValue': 0.0, 'liquidationValue': 21068.96, 'longMarketValue': 20195.15, 'moneyMarketFund': 0.0, 'savings': 0.0, 'shortMarketValue': 0.0, 'pendingDeposits': 0.0, 'mutualFundValue': 0.0, 'bondValue': 0.0, 'shortOptionMarketValue': 0.0, 'availableFunds': 10602.88, 'availableFundsNonMarginableTrade': 10602.88, 'buyingPower': 35342.93, 'buyingPowerNonMarginableTrade': 10602.88, 'dayTradingBuyingPower': 0.0, 'equity': 21068.96, 'equityPercentage': 100.0, 'longMarginValue': 20195.15, 'maintenanceCall': 0.0, 'maintenanceRequirement': 10466.08, 'marginBalance': 0.0, 'regTCall': 0.0, 'shortBalance': 0.0, 'shortMarginValue': 0.0, 'sma': 25060.0}, 'projectedBalances': {'availableFunds': 10602.88, 'availableFundsNonMarginableTrade': 10602.88, 'buyingPower': 35342.93, 'dayTradingBuyingPower': 0.0, 'dayTradingBuyingPowerCall': 0.0, 'maintenanceCall': 0.0, 'regTCall': 0.0, 'isInCall': False, 'stockBuyingPower': 35342.93}}, 'aggregatedBalance': {'currentLiquidationValue': 21068.96, 'liquidationValue': 21068.96}}

# %%
# get a list of quotes
print(client.quotes(["AAPL", "AMD"]).json())
# Out:
# {'AAPL': {'assetMainType': 'EQUITY', 'assetSubType': 'COE', 'quoteType': 'NBBO', 'realtime': True, 'ssid': 1973757747, 'symbol': 'AAPL', 'extended': {'askPrice': 0.0, 'askSize': 0, 'bidPrice': 0.0, 'bidSize': 0, 'lastPrice': 275.09, 'lastSize': 20, 'mark': 0.0, 'quoteTime': 1770886800000, 'totalVolume': 0, 'tradeTime': 1770886779000}, 'fundamental': {'avg10DaysVolume': 61226933.0, 'avg1YearVolume': 53916830.0, 'declarationDate': '2026-01-29T00:00:00Z', 'divAmount': 1.04, 'divExDate': '2026-02-09T00:00:00Z', 'divFreq': 4, 'divPayAmount': 0.26, 'divPayDate': '2026-02-12T00:00:00Z', 'divYield': 0.38001, 'eps': 7.46, 'fundLeverageFactor': 0.0, 'lastEarningsDate': '2026-01-29T00:00:00Z', 'nextDivExDate': '2026-05-11T00:00:00Z', 'nextDivPayDate': '2026-05-12T00:00:00Z', 'peRatio': 34.94166, 'sharesOutstanding': 14681140000}, 'quote': {'52WeekHigh': 288.62, '52WeekLow': 169.2101, 'askMICId': 'EDGX', 'askPrice': 265.32, 'askSize': 200, 'askTime': 1770915074790, 'bidMICId': 'XNAS', 'bidPrice': 265.29, 'bidSize': 200, 'bidTime': 1770915074627, 'closePrice': 275.5, 'highPrice': 275.72, 'lastMICId': 'XADF', 'lastPrice': 265.305, 'lastSize': 113, 'lowPrice': 265.0, 'mark': 265.305, 'markChange': -10.195, 'markPercentChange': -3.70054446, 'netChange': -10.195, 'netPercentChange': -3.70054446, 'openPrice': 275.59, 'postMarketChange': 0.0, 'postMarketPercentChange': 0.0, 'quoteTime': 1770915074790, 'securityStatus': 'Normal', 'totalVolume': 22990631, 'tradeTime': 1770915074781}, 'reference': {'cusip': '037833100', 'description': 'APPLE INC', 'exchange': 'Q', 'exchangeName': 'NASDAQ', 'isHardToBorrow': False, 'isShortable': True, 'htbQuantity': 38284417, 'htbRate': 0.0}, 'regular': {'regularMarketLastPrice': 265.305, 'regularMarketLastSize': 113, 'regularMarketNetChange': -10.195, 'regularMarketPercentChange': -3.70054446, 'regularMarketTradeTime': 1770915074781}}, 'AMD': {'assetMainType': 'EQUITY', 'assetSubType': 'COE', 'quoteType': 'NBBO', 'realtime': True, 'ssid': 1449199007, 'symbol': 'AMD', 'extended': {'askPrice': 0.0, 'askSize': 0, 'bidPrice': 0.0, 'bidSize': 0, 'lastPrice': 214.69, 'lastSize': 114, 'mark': 0.0, 'quoteTime': 1770886800000, 'totalVolume': 0, 'tradeTime': 1770886770000}, 'fundamental': {'avg10DaysVolume': 47619890.0, 'avg1YearVolume': 48009358.0, 'divAmount': 0.0, 'divFreq': 0, 'divPayAmount': 0.0, 'divYield': 0.0, 'eps': 2.61, 'fundLeverageFactor': 0.0, 'lastEarningsDate': '2026-02-04T00:00:00Z', 'peRatio': 81.83142, 'sharesOutstanding': 1630410843}, 'quote': {'52WeekHigh': 267.0799, '52WeekLow': 76.48, 'askMICId': 'XNAS', 'askPrice': 207.9, 'askSize': 200, 'askTime': 1770915074347, 'bidPrice': 207.79, 'bidSize': 100, 'bidTime': 1770915073830, 'closePrice': 213.58, 'highPrice': 218.4564, 'lastMICId': 'XADF', 'lastPrice': 207.82, 'lastSize': 100, 'lowPrice': 205.8373, 'mark': 207.82, 'markChange': -5.76, 'markPercentChange': -2.69688173, 'netChange': -5.76, 'netPercentChange': -2.69688173, 'openPrice': 215.83, 'postMarketChange': 0.0, 'postMarketPercentChange': 0.0, 'quoteTime': 1770915074347, 'securityStatus': 'Normal', 'totalVolume': 14838483, 'tradeTime': 1770915073519}, 'reference': {'cusip': '007903107', 'description': 'ADVANCED MICRO DEVIC', 'exchange': 'Q', 'exchangeName': 'NASDAQ', 'isHardToBorrow': False, 'isShortable': True, 'htbQuantity': 7827517, 'htbRate': 0.0}, 'regular': {'regularMarketLastPrice': 207.82, 'regularMarketLastSize': 100, 'regularMarketNetChange': -5.76, 'regularMarketPercentChange': -2.69688173, 'regularMarketTradeTime': 1770915073519}}}

# %%
# get an option chain
print(client.option_expiration_chain("AAPL").json())
# Out:
# {'expirationList': [{'expirationDate': '2026-02-13', 'daysToExpiration': 1, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-02-18', 'daysToExpiration': 6, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-02-20', 'daysToExpiration': 8, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-02-23', 'daysToExpiration': 11, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-02-25', 'daysToExpiration': 13, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-02-27', 'daysToExpiration': 15, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-03-06', 'daysToExpiration': 22, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-03-13', 'daysToExpiration': 29, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-03-20', 'daysToExpiration': 36, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-03-27', 'daysToExpiration': 43, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-04-02', 'daysToExpiration': 49, 'expirationType': 'W', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-04-17', 'daysToExpiration': 64, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-05-15', 'daysToExpiration': 92, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-06-18', 'daysToExpiration': 126, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-07-17', 'daysToExpiration': 155, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-08-21', 'daysToExpiration': 190, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-09-18', 'daysToExpiration': 218, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-11-20', 'daysToExpiration': 281, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2026-12-18', 'daysToExpiration': 309, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2027-01-15', 'daysToExpiration': 337, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2027-06-17', 'daysToExpiration': 490, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2027-12-17', 'daysToExpiration': 673, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2028-01-21', 'daysToExpiration': 708, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2028-03-17', 'daysToExpiration': 764, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}, {'expirationDate': '2028-12-15', 'daysToExpiration': 1037, 'expirationType': 'S', 'settlementType': 'P', 'optionRoots': 'AAPL', 'standard': True}], 'status': None}

# %% [markdown]
# # Order example
# This **WILL** place an on your account.

# %%
# place an order for INTC at limit price $10.00
order = {"orderType": "LIMIT", 
         "session": "NORMAL", 
         "duration": "DAY", 
         "orderStrategyType": "SINGLE", 
         "price": '10.00',
         "orderLegCollection": [
             {"instruction": "BUY", 
              "quantity": 1, 
              "instrument": 
                  {"symbol": "INTC", 
                   "assetType": "EQUITY"
                   }
              }
         ]}
resp = client.place_order(account_hash, order)
print(f"Response code: {resp}") 

# get the order ID - if order is immediately filled then the id might not be returned
order_id = resp.headers.get('location', '/').split('/')[-1] 
print(f"Order id: {order_id}")

# %%
# cancel the order
print(client.cancel_order(account_hash, order_id))

# %% [markdown]
# # Streaming example

# %%
# create streamer
streamer = schwabdev.Stream(client)

# %%
# create a list to store responses
responses = []
def add_to_list(message):
    responses.append(message)

# %%
#start stream and send request
streamer.start(add_to_list)
streamer.send(streamer.level_one_equities("AMD", "0,1,2,3,4,5,6,7,8"))
# Out:
# INFO:Schwabdev:Stream is not active, request queued.

# %%
#check responses REMEMBER: the stream is running in the background so the responses list will change on subsequent reruns)
print(responses)
# Out:
# ['{"response":[{"service":"ADMIN","command":"LOGIN","requestid":"1","SchwabClientCorrelId":"b22e4225-ac8f-1808-8634-26f4fce24188","timestamp":1770915104014,"content":{"code":0,"msg":"server=s0635dc6-4;status=NP"}}]}', '{"response":[{"service":"LEVELONE_EQUITIES","command":"ADD","requestid":"3","SchwabClientCorrelId":"b22e4225-ac8f-1808-8634-26f4fce24188","timestamp":1770915104091,"content":{"code":0,"msg":"ADD command succeeded"}}]}', '{"data":[{"service":"LEVELONE_EQUITIES", "timestamp":1770915104115,"command":"SUBS","content":[{"key":"AMD","delayed":false,"assetMainType":"EQUITY","assetSubType":"COE","cusip":"007903107","1":208.01,"2":208.14,"3":208.07,"4":100,"5":100,"6":"Q","7":"K","8":14870246}]}]}', '{"data":[{"service":"LEVELONE_EQUITIES", "timestamp":1770915105159,"command":"SUBS","content":[{"key":"AMD","2":208.15,"3":208.115,"8":14871321}]}]}', '{"data":[{"service":"LEVELONE_EQUITIES", "timestamp":1770915106190,"command":"SUBS","content":[{"key":"AMD","2":208.14,"3":208.075,"6":"G","8":14871724}]}]}', '{"data":[{"service":"LEVELONE_EQUITIES", "timestamp":1770915107235,"command":"SUBS","content":[{"key":"AMD","8":14873074}]}]}']

# %%
#stop stream
streamer.stop()
